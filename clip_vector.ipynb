# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
from matplotlib.colors import ListedColormap
import geopandas as gpd

from shapely.geometry import box
import earthpy as et
import seaborn as sns

import warnings
warnings.filterwarnings('ignore', 'GeoSeries.notna', UserWarning)

sns.set(font_scale=1.5)
sns.set_style("white")

data = et.data.get_data('spatial-vector-lidar')
os.chdir(os.path.join(et.io.HOME, 'earth-analytics'))

# %%
country_boundary_us_path = os.path.join("data", "spatial-vector-lidar", "usa", "usa-boundary-dissolved.shp")
country_boundary_us = gpd.read_file(country_boundary_us_path)

state_boundary_us_path = os.path.join("data", "spatial-vector-lidar", "usa", "usa-states-census-2014.shp")
state_boundary_us = gpd.read_file(state_boundary_us_path)

pop_places_path = os.path.join("data", "spatial-vector-lidar", "global", "ne_110m_populated_places_simple", "ne_110m_populated_places_simple.shp")
pop_places = gpd.read_file(pop_places_path)

print("country_boundary_us", country_boundary_us.crs)
print("state_boundary_us", state_boundary_us.crs)
print("pop_places", pop_places.crs)
# Out:
# country_boundary_us EPSG:4326
# state_boundary_us EPSG:4326
# pop_places EPSG:4326

# %%
fig, ax = plt.subplots(figsize=(12, 8))

country_boundary_us.plot(alpha=.5, ax=ax)
state_boundary_us.plot(cmap='Greys', ax=ax, alpha=.5)
pop_places.plot(ax=ax)

plt.axis('equal')
ax.set_axis_off()
plt.show()

# %%
points_clip = gpd.clip(pop_places, country_boundary_us)

points_clip[['name', 'geometry', 'scalerank', 'natscale', ]].head()
# Out:
#               name                     geometry  scalerank  natscale
# 178          Miami   POINT (-80.22605 25.78956)          1       300
# 177        Houston   POINT (-95.34193 29.82192)          1       300
# 179        Atlanta   POINT (-84.40190 33.83196)          1       300
# 216    Los Angeles  POINT (-118.18193 33.99192)          0       600
# 175  San Francisco  POINT (-122.41717 37.76920)          1       300

# %%
fig, ax = plt.subplots(figsize=(12, 8))

country_boundary_us.plot(alpha=1, color="pink", edgecolor="black", ax=ax)
state_boundary_us.plot(cmap='Greys', ax=ax, alpha=.5)

points_clip.plot(ax=ax, column='name')
ax.set_axis_off()
plt.axis('equal')

points_clip.apply(lambda x: ax.annotate(s=x['name'], xy=x.geometry.coords[0], xytext=(6, 6), textcoords="offset points", backgroundcolor="white"), axis=1)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 10
#       7 ax.set_axis_off()
#       8 plt.axis('equal')
# ---> 10 points_clip.apply(lambda x: ax.annotate(s=x['name'], xy=x.geometry.coords[0], xytext=(6, 6), textcoords="offset points", backgroundcolor="white"), axis=1)
#      12 plt.show()
#
# File ~/.python/current/lib/python3.10/site-packages/geopandas/geodataframe.py:1571, in GeoDataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    1569 @doc(pd.DataFrame)
#    1570 def apply(self, func, axis=0, raw=False, result_type=None, args=(), **kwargs):
# -> 1571     result = super().apply(
#    1572         func, axis=axis, raw=raw, result_type=result_type, args=args, **kwargs
#    1573     )
#    1574     # pandas <1.4 re-attach last geometry col if lost
#    1575     if (
#    1576         not compat.PANDAS_GE_14
#    1577         and isinstance(result, GeoDataFrame)
#    1578         and result._geometry_column_name is None
#    1579     ):
#
# File ~/.python/current/lib/python3.10/site-packages/pandas/core/frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File ~/.python/current/lib/python3.10/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~/.python/current/lib/python3.10/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~/.python/current/lib/python3.10/site-packages/pandas/core/apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[16], line 10, in <lambda>(x)
#       7 ax.set_axis_off()
#       8 plt.axis('equal')
# ---> 10 points_clip.apply(lambda x: ax.annotate(s=x['name'], xy=x.geometry.coords[0], xytext=(6, 6), textcoords="offset points", backgroundcolor="white"), axis=1)
#      12 plt.show()
#
# TypeError: Axes.annotate() missing 1 required positional argument: 'text'

# %%
ne_roads_path = os.path.join("data", "spatial-vector-lidar", "global", "ne_10m_roads", "ne_10m_roads.shp")
ne_roads = gpd.read_file(ne_roads_path)

# %%
if (ne_roads.crs == country_boundary_us.crs):
    print("Both layers are in the same crs!",
          ne_roads.crs, country_boundary_us.crs)
# Out:
# Both layers are in the same crs! EPSG:4326 EPSG:4326

# %%
ne_roads_clip = gpd.clip(ne_roads, country_boundary_us)

ne_roads_clip = ne_roads_clip[~ne_roads_clip.is_empty]

print("The clipped data have fewer line objects", ne_roads_clip.shape, ne_roads.shape)
# Out:
# The clipped data have fewer line objects (7363, 32) (56601, 32)

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 10))

ne_roads.plot(ax=ax1)
ne_roads_clip.plot(ax=ax2)

ax1.set_title("Unclipped roads")
ax2.set_title("Clipped roads")

ax1.set_axis_off()
ax2.set_axis_off()

plt.axis('equal')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 8))

country_boundary_us.plot(alpha=1, color="white", edgecolor="black", ax=ax)

ne_roads_clip.plot(ax=ax)

ax.set_axis_off()
plt.axis('equal')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 10))

country_boundary_us.simplify(2, preserve_topology=True).plot(ax=ax1)

country_boundary_us.simplify(.2, preserve_topology=True).plot(ax=ax2)

ax1.set_title(
    "Data with a higher tolerance value will become visually blockier as there are fewer vertices")
ax2.set_title(
    "Data with a very low tolerance value will look smoother but will take longer to process")

ax1.set_axis_off()
ax2.set_axis_off()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 8))

country_boundary_us.plot(alpha=1, color="pink", edgecolor="black", ax=ax)

ne_roads_clip.plot(ax=ax, column='type', legend=True)

ax.set_axis_off()
plt.axis('equal')
plt.show()

# %%
road_attrs = {'Beltway': ['black', 2], 'Secondary Highway': ['red', .5], 'Road': ['Grey', .5], 'Bypass': ['grey', .5], 'Ferry Route': ['grey', .5], 'Major Highway': ['blue', 1]}

fig, ax = plt.subplots(figsize=(12, 8))

for ctype, data in ne_roads_clip.groupby('type'):
    data.plot(color=road_attrs[ctype][0], label=ctype, ax=ax, linewidth=road_attrs[ctype][1])

country_boundary_us.plot(alpha=1, color="yellow", edgecolor="blue", ax=ax)

ax.legend(frameon=False, 
          loc = (0.1, -0.1))

ax.set_title("United States Roads by Type", fontsize=25)
ax.set_axis_off()

plt.axis('equal')
plt.show()
