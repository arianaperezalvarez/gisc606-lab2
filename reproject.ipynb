# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd
import earthpy as et

sns.set_style("white")
sns.set(font_scale=1.5)

data = et.data.get_data('spatial-vector-lidar')
os.chdir(os.path.join(et.io.HOME, 'earth-analytics'))

# %%
sjer_roads_path = os.path.join("data", "spatial-vector-lidar", "california", "madera-county-roads", "tl_2013_06039_roads.shp")
sjer_roads = gpd.read_file(sjer_roads_path)

sjer_aoi_path = os.path.join("data", "spatial-vector-lidar", "california", "neon-sjer-site", "vector_data", "SJER_crop.shp")
sjer_aoi = gpd.read_file(sjer_aoi_path)

print(sjer_roads.crs)
print(sjer_aoi.crs)
# Out:
# EPSG:4269
# EPSG:32611

# %%
sjer_aoi_wgs84  = sjer_aoi.to_crs(epsg=4269)

# %%
fig, ax = plt.subplots(figsize=(12, 8))

sjer_roads.plot(cmap='Greys', ax=ax, alpha=.5)
sjer_aoi_wgs84.plot(ax=ax, markersize=10, color='r')

ax.set_title("Madera County Roads with SJER AOI");

# %%
state_boundary_us_path = os.path.join("data", "spatial-vector-lidar", "usa", "usa-states-census-2014.shp")
state_boundary_us = gpd.read_file(state_boundary_us_path)

type(state_boundary_us)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
state_boundary_us.head()
# Out:
#   STATEFP   STATENS     AFFGEOID GEOID STUSPS                  NAME LSAD  \
# 0      06  01779778  0400000US06    06     CA            California   00
# 1      11  01702382  0400000US11    11     DC  District of Columbia   00
# 2      12  00294478  0400000US12    12     FL               Florida   00
# 3      13  01705317  0400000US13    13     GA               Georgia   00
# 4      16  01779783  0400000US16    16     ID                 Idaho   00
#
#           ALAND       AWATER     region  \
# 0  403483823181  20483271881       West
# 1     158350578     18633500  Northeast
# 2  138903200855  31407883551  Southeast
# 3  148963503399   4947080103  Southeast
# 4  214045425549   2397728105       West
#
#                                             geometry
# 0  MULTIPOLYGON Z (((-118.59397 33.46720 0.00000,...
# 1  POLYGON Z ((-77.11976 38.93434 0.00000, -77.04...
# 2  MULTIPOLYGON Z (((-81.81169 24.56874 0.00000, ...
# 3  POLYGON Z ((-85.60516 34.98468 0.00000, -85.47...
# 4  POLYGON Z ((-117.24303 44.39097 0.00000, -117....

# %%
fig, ax = plt.subplots(figsize = (12,8))
state_boundary_us.plot(ax = ax, facecolor = 'green', edgecolor = 'purple')

ax.set(title="Map of Continental US State Boundaries\n United States Census Bureau Data")

plt.axis('equal')
ax.set_axis_off()

plt.show()

# %%
county_boundary_us_path = os.path.join("data", "spatial-vector-lidar", "usa", "usa-boundary-dissolved.shp")
county_boundary_us = gpd.read_file(county_boundary_us_path)

type(county_boundary_us)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
fig, ax = plt.subplots(figsize = (12,7))
country_boundary_us.plot(ax=ax, alpha=1, edgecolor="purple", color = "purple", linewidth=4)
state_boundary_us.plot(ax = ax, color = "yellow", edgecolor = "purple", linewidth = 1)

ax.set_axis_off()
plt.show()

# %%
fig, ax=plt.subplots(figsize=(6,6))

sjer_aoi.plot(ax=ax, color="indigo")

ax.set(title="SJER\nAOI")

ax.set_axis_off()

plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 6))

country_boundary_us.plot(ax=ax, 
                         edgecolor="black",
                         color = "blue",
                         linewidth=3, 
                         alpha=.8)

state_boundary_us.plot(ax = ax, 
                       color = "blue", 
                       edgecolor ="gray")
sjer_aoi.plot(ax=ax, color = "indigo")

ax.set_axis_off()
plt.show()

# %%
print(sjer_aoi.crs)
print(country_boundary_us.crs)
print(state_boundary_us.crs)
# Out:
# EPSG:32611
# EPSG:4326
# EPSG:4326

# %%
print(sjer_aoi.total_bounds)
print(state_boundary_us.total_bounds)
# Out:
# [ 254570.567      4107303.07684455  258867.40933092 4112361.92026107]
# [-124.725839   24.498131  -66.949895   49.384358]

# %%
sjer_aoi_WGS84 = sjer_aoi.to_crs(state_boundary_us.crs)

print(sjer_aoi.total_bounds)
print('sjer_aoi crs: ', sjer_aoi_WGS84.crs)
print('state boundary crs:', state_boundary_us.crs)
# Out:
# [ 254570.567      4107303.07684455  258867.40933092 4112361.92026107]
# sjer_aoi crs:  EPSG:4326
# state boundary crs: EPSG:4326

# %%
sjer_aoi_WGS84_2 = sjer_aoi.to_crs("+proj=longlat +ellps=WGS84 +datum=WGS84 +no_defs")

# %%
fig, ax = plt.subplots(figsize = (12,8))

state_boundary_us.plot(ax = ax,
                      linewidth=1,
                      edgecolor="black")

country_boundary_us.plot(ax=ax,
                         alpha=.5, 
                         edgecolor="black",
                         color = "white",
                         linewidth=3)
sjer_aoi_WGS84.plot(ax=ax, 
                    color='springgreen',
                   edgecolor = "r")

ax.set(title="Map of Continental US State Boundaries \n with SJER AOI")
# Out:
# [Text(0.5, 1.0, 'Map of Continental US State Boundaries \n with SJER AOI')]

# %%
fig, ax = plt.subplots(figsize = (12,8))

state_boundary_us.plot(ax = ax,
                      linewidth=1,
                      edgecolor="black")

country_boundary_us.plot(ax=ax,
                         alpha=.5, 
                         edgecolor="black",
                         color = "white",
                         linewidth=3)

sjer_aoi_WGS84.plot(ax=ax, 
                    color='springgreen',
                   edgecolor = "r")

ax.set(title="Map of Continental US State Boundaries \n with SJER AOI")
ax.set(xlim=[-125, -116], ylim=[35, 40])

ax.set(xticks = [], yticks = []);

# %%
AOI_point = sjer_aoi_WGS84["geometry"].centroid
type(AOI_point)
# Out:
# /tmp/ipykernel_31284/657144365.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   AOI_point = sjer_aoi_WGS84["geometry"].centroid
# geopandas.geoseries.GeoSeries

# %%
sjer_aoi_WGS84["geometry"].centroid.plot();
# Out:
# /tmp/ipykernel_31284/709454386.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   sjer_aoi_WGS84["geometry"].centroid.plot();

# %%
fig, ax = plt.subplots(figsize = (12,7))

state_boundary_us.plot(ax = ax,
                      linewidth=1,
                      edgecolor="black")

country_boundary_us.plot(ax=ax,
                         alpha=.7, 
                         edgecolor="black",
                         color = "white",
                         linewidth=3)

AOI_point.plot(ax=ax,
              markersize=80,
              color='purple',
              marker='*')

ax.set(title="Map of Continental US State Boundaries \n with SJER AOI")

ax.set_axis_off();
